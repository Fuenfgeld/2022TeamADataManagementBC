# %% [markdown]
# <a href="https://colab.research.google.com/github/Fuenfgeld/2022TeamADataManagementBC/blob/main/DataManagementBootcamp/Einf%C3%BChrung_Metadaten.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Metadaten
#
# *“Metadaten sind strukturierte Informationen, die beschreiben, erklären,
# lokalisieren, oder es sonstwie einfacher machen, eine
# Informationsquelle abzurufen, zu verwenden, oder zu verwalten.
# Metadaten werden oft Daten zu bestimmten Daten oder Informationen
# zu bestimmten Informationen genannt.”*
# -- National Information Standards Organization
#
# [http://www.niso.org/publications/understanding-metadata-2017](http://www.niso.org/publications/understanding-metadata-2017)
#
# Metadaten liefern die nötigen Informationen dafür, dass Daten (z.B.
# Dokumente, Bilder, Datensätze), Konzepte (z.B. Klassifikationen) und
# reale Begebenheiten (z.B. Personen, Organisationen, Standorte,
# Bilder, Produkte) zusammenpassen.

# %% [markdown]
# # Arten von Metadaten
#
#
# *   Beschreibende Metadaten
#   * beschreiben eine Ressource für die Zwecke der Entdeckung und der Identifizierung
# *   Strukturelle Metadaten
#   * z.B. Datenmodelle und Referenzdaten
# *   Administrative Metadaten
#   * bieten Informationen zur Verwaltung
# einer Ressource

# %% [markdown]
# # Metadatenbeispiel aus der analogen Welt
#
# Nicht nur digitale Erzeugnisse enthalten Metadaten. Welche Metadaten könnte es bei einem Buch geben?

# %% [markdown]
# **Schreibe hier deine Vermutungen:**
# 1.
# 2.
# 3.
# ...

# %% [markdown]
# **Lösung**
# 1. Name des Autors
# 2. Auflage
# 3. Erscheinungsjahr
# 4. Verlag
# 5. ISBN-Nummer

# %% [markdown]
# # Metadatenstandards
# Um zum Beispiel Studien vergleichbar oder auch nachvollziehbar zu machen sind interoperable Metadaten essentiell.
#
# Interoperable Metadaten sind Metadaten aus potenziell unterschiedlichen Quellen, zwischen denen eine Beziehung in der Weise besteht, dass mit ihnen gemeinsam gearbeitet werden kann.
#
# Standards für interoperable Metadaten haben die Aufgabe, Metadaten aus unterschiedlichen Quellen nutzbar zu machen.
#
# Ein weit verbreiteter Standard für die bibliographische Beschreibung von Forschungsdaten ist das Metadatenschema zur Registrierung von DOIs (digital object identifiers) von DataCite. Dieses gibt vor, welche Information zu einem Datensatzes verpflichtend angegeben werden müssen (z. B. Autor, Titel), welche Angaben empfohlen werden (z. B. Fachbereich, Beschreibung) und welche optional sind (z. B. Finanzierung, Nutzungsrechte). Diese und weitere Metadaten werden im XML-Format für die interoperable Nutzung zur Verfügung gestellt.
#
# ## Weitere Standards
#
#
# *   PREMIS
#   * administrative Metadaten in der Langzeitarchivierung
# *   METS (Metadata Encoding & Transmission Standard)
#
#
# ## Übersicht weiterer fachspezifischer Standards
#
#
# *   Metadata Standards Catalog
# *   RDA Metadata Standards Directory Working Group
# *   FairSharing.org
# *   DDC (Digital Curation Centre)

# %% [markdown]
# # Metadatenschema
#
# Metadatenschemata sind Zusammenstellungen von Elementen zur Beschreibung von Daten.
#
# Da Informationen für das Auffinden, das Verständnis und die Nutzung von Daten essentiell sind, sollten standardisierte Metadatenschemata eine möglichst einheitliche und nachvollziehbare Beschreibung sicherstellen.
#
# Sollte kein fachspezifisches Schema zur Verfügung stehen, kann auch ein disziplinunabhängiges genutzt werden (z.B. Dublin Core, MARC21 oder RADAR). Metadatenschemata legen fest, welche Informationen geliefert werden sollen.
#
# Eine Dokumentation geht in der Regel über die Beschreibung der Daten via Metadaten hinaus. Sie stellt eine tiefere, fachwissenschaftliche Erschließung dar, in deren Rahmen z.B. Entstehungskontext, Variablen, Instrumente, Methoden etc. ausführlich beschrieben werden. In vielen Fällen ist eine solche Beschreibung unerlässlich, um die Daten verstehen, nachprüfen und ggf. nachnutzen zu können.
#
# ## Dublin-Core
# Im allgemeinen Dublin-Core Metadatenschema werden folgende 15 Kategorien erfasst:
# 1. Coverage
# 2. Description
# 3. Language
# 4. Relation
# 5. Source
# 6. Subjet
# 7. Title
# 8. Author / creator
# 9. Contributor
# 10. Publisher
# 11. Rights
# 12. Date
# 13. Format
# 14. Identifier
# 15. Type
#
# Dieses disziplinunabhäniges Schema stellt alle dokumentierten Metadetn im XML Format bereit und bietet über diese 15 standard Kategorien noch unzählige weitere Kategorien.

# %% [markdown]
# ![Metadaten vs Daten.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # Übung: Erste explorative Analyse des Datensatzes und er Metadaten
#
# Schaut euch den nachfolgenden Datensatz an:
# https://www.kaggle.com/datasets/sulianova/cardiovascular-disease-dataset
#
#
# Versuche nun zunächst die folgenden allgemeinen Fragen zu beantworten:
# *   Wer besitzt die Daten
# *   Woher kommen die Daten?
# *   Zugriffrechte der Daten / Welche Lizenz?
# *   Wo werden die Daten genutz/geteilt?
# *   Wann wurden die Daten erstellt/geändert?
# *   Datum der einzelnen Messungen vorhanden?

# %% [markdown]
# ### Lösung Allgemeine Infos
#
# *   Wer besitzt die Daten?
#   * Svetlana Ulianova (Owner)
# *   Woher kommen die Daten?
#   * Alle Datensatzwerte wurden zum Zeitpunkt der ärztlichen Untersuchung erhoben.
# *   Zugriffrechte der Daten / Welche Lizenz?
#   * Public/Unknown
# *   Wo werden die Daten genutz/geteilt?
#   * Kaggle
# *   Benutzung/Vewendung der Daten?
#   * Klassifizierung von Herzkrankheiten
# *   Wann wurden die Daten erstellt/geändert?
#   * 2019
# *   Datum der einzelnen Aufnahmen?
#   * Nicht vorhanden

# %% [markdown]
# # Übung: Metadatenschema ausfüllen
#
# Analysiere nun den Datensatz genauer, welche Informationen kannst du finden?
# Füge hierzu in die erstellte Tabelle alle potentiellen Metadaten und deren Informationen hinzu die du finden kannst.

# %% [markdown]
# | Feld | Inhalt | Format | Referenz |
# | --- | --- | --- | --- |
# | age | Alter der Probanden | int (Tage) | NA
# | ap_hi | Systolischer Blutdruck | int | NA
# |  |  |  |
# |  |  |  |
# |  |  |  |
# |  |  |  |
# |  |  |  |

# %% [markdown]
# ## Lösung Metadatenschema

# %% [markdown]
# # Diskussion
# 1.   Sind alle Informationen zugänglich/vorhanden?
#   * Falls nein, was fehlt?
# 2.   Handelt es sich hierbei um einen gut annotierten Datensatz?
#   * Falls nein, was müsste verändert werden?

# %% [markdown]
# ### Lösung Diskussion
